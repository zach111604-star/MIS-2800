# %% [markdown]
# <a href="https://colab.research.google.com/github/zach111604-star/MIS-2800/blob/main/Anderson_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# !pip install ipython-sql
print ("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print ("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT ;
# print ("done")
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# (sqlite3.OperationalError) near "print": syntax error
# [SQL: print ("done")]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
# (1, 'Doritos', 'Snacks', 7000000),
# (2, 'AWS', 'Technology', 15000000),
# (3, 'Pepsi', 'Beverage', 2000000),
# (4, 'He_Gets-Us', 'Religious', 1000000),
# (5, 'Dr_Pepper', 'Beverage', 5000000),
# (6, 'IBM', 'Technology', 100000),
# (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverage', 2000000),
#  (4, 'He_Gets-Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverage', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name FROM Marketing_Brands WHERE brand_budget >700000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',),
#  ('AWS',),
#  ('Pepsi',),
#  ('He_Gets-Us',),
#  ('Dr_Pepper',),
#  ('Google',)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_type = 'Religious'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets-Us', 'Religious', 1000000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_budget <1000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_budget >700000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverage', 2000000),
#  (4, 'He_Gets-Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverage', 5000000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverage'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets-Us', 1000000),
#  ('IBM', 100000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets-Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverage', 2000000),
#  (5, 'Dr_Pepper', 'Beverage', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. I fixed the error by adding 'table' into create table

# %% [markdown]
# 2. I fixed the error by adding 'into' after insert to show where to put the data

# %% [markdown]
# 3. I fixed the error by adding a '*' inbetween select and from

# %% [markdown]
# 4. I fixed the error by adding 'brand_name' after select and added the 'where brand_budget > 700000'

# %% [markdown]
# 5. I fixed the error by adding the '*' inbetween the select and from also added the 'where brand_type = religious'

# %% [markdown]
# 6. I fixed the error by adding the '*' inbetween select and from also 'where brand_budget <1000000

# %% [markdown]
# 7. I fixed the error by adding the %%sql at the top of the function

# %% [markdown]
# 8. I fixed the error by adding the 'brand_name' after select also added 'where brand_type = snacks or where brand_type = beverage

# %% [markdown]
# 9. I fixed the error by selecting what data to show such as the brand_name and brand_ budget to then put them in descending order based on their budget by adding 'ORDER BY'

# %% [markdown]
# 10. I fixed the error by writing out the whole sequence by hand adding all vital information
