# %% [markdown]
# <a href="https://colab.research.google.com/github/zach111604-star/MIS-2800/blob/main/Anderson_IC6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: The Business Impact (Lyft Case Study)

# %% [markdown]
# **Lyft Video**: https://aws.amazon.com/solutions/case-studies/lyft/
#
# **Watch the Lyft video and consider the following:**
#
# 1. The Innovation: How did moving from simple data storage to a Redshift data warehouse allow Lyft to transition from "just tracking rides" to "creating new products" like Lyft Line?
#
#
# 2. Real-time vs. Strategic: Lyft uses different tools for their app (OLTP) than they do for their planning (OLAP). Why can't they just use the same database for both?

# %% [markdown]
# ## YOUR ANSWERS TO PART 1 BELOW

# %% [markdown]
# Question 1: By having all of the data in one area the data team was then able to look at multiple orders who may have similarities and find a pattern that they could implement new designs and products.
#
#
# Question 2: They cannot use the same tools for apps and planning as they deal with two different functions. The app model allows users to place orders for pickups and drop-offs. While the model used for planning is for the workers through Lyft who will be driving the users. They need to have different information and data to compelte their job and complete the task.

# %% [markdown]
# ## Part 2: The Infrastructure (AWS Skill Builder)
#
# **Instructions**
#
#
# 1.   Create a free AWS Skill Builder account https://scribehow.com/viewer/AWS_Skillbuilder_and_Eduate__Souc1HOKQbiiJnktuVgSEQ
# 2.   Complete the "Introduction" and "Architecture" modules in AWS Skill Builder. Instructions are here: https://www.loom.com/share/530dd0536c2c44729fe9a6ed26f7f162
#
# # Answer the Questions
#
# 1. Scaling the Design: In DataCamp, we practiced Normalization. In the Redshift architecture, why is "Columnar Storage" often more important for an analyst than having perfectly normalized tables? https://docs.aws.amazon.com/redshift/latest/dg/c_columnar_storage_disk_mem_mgmnt.html
#
# 2. Speed to Insight: How does the architecture of a "Leader Node" and "Compute Nodes" change how quickly a Business Intelligence report is generated?  https://docs.aws.amazon.com/redshift/latest/dg/c_high_level_system_architecture.html

# %% [markdown]
# ## YOUR ANSWERS TO PART 2 BELOW

# %% [markdown]
# Question 1: Columnar storage is more important than normalization because analytics workloads focus on reading large amounts of data quickly which is easier done in redshift rather than minimizing redundancies like in normalized tables.
#
# Question 2: In Amazon Redshift, the Leader Node + Compute Nodes architecture is designed specifically to make large analytical queries like Business Intelligence reports run much faster by using parallel processing.

# %% [markdown]
# ## Part 3: Strategic Reflection
#
# 1. The Management Perspective: As a future business leader, how does knowing the capabilities of a tool like Redshift change the questions you would ask your data team?
#
# 2. The ETL Bridge: Reflect on the ETL process. If you were a manager at an organization, why is the "Clean and Load" phase the most critical part of your BI strategy?

# %% [markdown]
# ## YOUR ANSWERS TO PART 3 BELOW

# %% [markdown]
# Question 1: Knowing the capabilities of Amazon Redshift changes how a future business leader communicates with a data team because it helps you ask strategic, data driven questions focused on speed, scalability, and decision making, instead of only asking for simple reports.
#
# Question 2: In the clean and load phase it determines whether the data used for decision-making is accurate, consistent, and trustworthy. Even powerful analytics tools or data warehouses like Amazon Redshift cannot produce good insights if poor-quality data is loaded into them.
